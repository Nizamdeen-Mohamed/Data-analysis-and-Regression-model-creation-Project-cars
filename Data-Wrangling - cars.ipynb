# %% [markdown]
# # Data Wrangling
#
#
#
#
# ## Objectives
#
#
# * Handle missing values
# * Correct data formatting
# * Standardize and normalize data

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ul>
#     <li><a href="#Identify-and-handle-missing-values">Identify and handle missing values</a>
#         <ul>
#             <li><a href="#Identify-missing-values">Identify missing values</a></li>
#             <li><a href="#Deal-with-missing-data">Deal with missing values</a></li>
#             <li><a href="#Correct-data-format">Correct data format</a></li>
#         </ul>
#     </li>
#     <li><a href="#Data-Standardization">Data standardization</a></li>
#     <li><a href="#Data-Normalization">Data normalization (centering/scaling)</a></li>
#     <li><a href="#Binning">Binning</a></li>
#     <li><a href="#Indicator-Variable">Indicator variable</a></li>
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <h4>Import pandas</h4>

# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
# !pip install aiohttp
# Out:
# Requirement already satisfied: aiohttp in c:\users\admin\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp) (4.0.3)
# Requirement already satisfied: idna>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp) (3.4)

# %%
import aiohttp

async def download(url, filename):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                with open(filename, "wb") as f:
                    f.write(await response.read())
                    

# Now you can call the download function
# For example:
# await download('https://example.com/file.txt', 'downloaded_file.txt')

# %%
file_path="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"

# %%
await download(file_path, "usedcars.csv")
file_name="usedcars.csv"

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df = pd.read_csv(file_name, names = headers)

# %%
# To see what the data set looks like, we'll use the head() method.
pd.set_option('display.max_columns', None)#we can look out for max data  
pd.set_option('display.max_rows', None) 

df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %% [markdown]
# As you can see, several question marks appeared in the data frame; those missing values may hinder further analysis.

# %% [markdown]
# # Identify and handle missing values

# %%
import numpy as np
df.replace("?",np.nan, inplace = True)

# %%
import numpy as np

# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  length  width  \
# 0       False         False            False       False   False  False
# 1       False         False            False       False   False  False
# 2       False         False            False       False   False  False
# 3       False         False            False       False   False  False
# 4       False         False            False       False   False  False
#
#    height  curb-weight  engine-type  num-of-cylinders  engine-size  \
# 0   False        False        False             False        False
# 1   False        False        False             False        False
# 2   False        False        False             False        False
# 3   False        False        False             False        False
# 4   False        False        False             False        False
#
#    fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        False  False   False              False       False     False
# 1        False  False   False              False       False     False
# 2        False  False   False              False       False     False
# 3        False  False   False              False       False     False
# 4        False  False   False              False       False     False
#
#    city-mpg  highway-mpg  price
# 0     False        False  False
# 1     False        False  False
# 2     False        False  False
# 3     False        False  False
# 4     False        False  False

# %% [markdown]
# <h4>Count missing values in each column</h4>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    205
# Name: num-of-cylinders, dtype: int64
#
# engine-size
# False    205
# Name: engine-size, dtype: int64
#
# fuel-system
# False    205
# Name: fuel-system, dtype: int64
#
# bore
# False    201
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    201
# True       4
# Name: stroke, dtype: int64
#
# compression-ratio
# False    205
# Name: compression-ratio, dtype: int64
#
# horsepower
# False    203
# True       2
# Name: horsepower, dtype: int64
#
# peak-rpm
# False    203
# True       2
# Name: peak-rpm, dtype: int64
#
# city-mpg
# False    205
# Name: city-mpg, dtype: int64
#
# highway-mpg
# False    205
# Name: highway-mpg, dtype: int64
#
# price
# False    201
# True       4
# Name: price, dtype: int64

# %% [markdown]
# Based on the summary above, each column has 205 rows of data and seven of the columns containing missing data:
# <ol>
#     <li>"normalized-losses": 41 missing data</li>
#     <li>"num-of-doors": 2 missing data</li>
#     <li>"bore": 4 missing data</li>
#     <li>"stroke" : 4 missing data</li>
#     <li>"horsepower": 2 missing data</li>
#     <li>"peak-rpm": 2 missing data</li>
#     <li>"price": 4 missing data</li>
# </ol>

# %% [markdown]
# <b>Replace by mean:</b>
# <ul>
#     <li>"normalized-losses": 41 missing data, replace them with mean</li>
#     <li>"stroke": 4 missing data, replace them with mean</li>
#     <li>"bore": 4 missing data, replace them with mean</li>
#     <li>"horsepower": 2 missing data, replace them with mean</li>
#     <li>"peak-rpm": 2 missing data, replace them with mean</li>
# </ul>
#
# <b>Replace by frequency:</b>
# <ul>
#     <li>"num-of-doors": 2 missing data, replace them with "four".
#         <ul>
#             <li>Reason: 84% sedans are four doors. Since four doors is most frequent, it is most likely to occur</li>
#         </ul>
#     </li>
# </ul>
#
# <b>Drop the whole row:</b>
# <ul>
#     <li>"price": 4 missing data, simply delete the whole row
#         <ul>
#             <li>Reason: You want to predict price. You cannot use any data entry without price data for prediction; therefore any row now without price data is not useful to you.</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h4>the mean value for the "normalized-losses" column </h4>

# %%
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %% [markdown]
# <h4>Replace "NaN" with mean value in "normalized-losses" column</h4>

# %%
df["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)

# %% [markdown]
# <h4> the mean value for the "bore" column</h4>

# %%
avg_bore=df['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3297512437810943

# %% [markdown]
# <h4>Replace "NaN" with the mean value in the "bore" column</h4>

# %%
df["bore"].replace(np.nan, avg_bore, inplace=True)

# %%
average_stroke = df['stroke'].astype('float').mean(axis = 0)
average_stroke 

df['stroke'].replace(np.nan,average_stroke, inplace = True)
df['stroke']
# Out:
# 0          2.68
# 1          2.68
# 2          3.47
# 3          3.40
# 4          3.40
# 5          3.40
# 6          3.40
# 7          3.40
# 195        3.15
# 196        3.15
# 197        3.15
# 198        3.15
# 199        3.15
# 200        3.15
# 201        3.15
# 202        2.87
# 203        3.40
# 204        3.15
# Name: stroke, dtype: object

# %% [markdown]
# <h4>the mean value for the "horsepower" column</h4>

# %%
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)
# Out:
# Average horsepower: 104.25615763546799

# %% [markdown]
# <h4>"NaN" with the mean value in the "horsepower" column</h4>

# %%
df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)
print("avg_horsepower:", df['horsepower'])
# Out:
# avg_horsepower: 0             111
# 1             111
# 2             154
# 3             102
# 4             115
# 5             110
# 6             110
# 7             110
# 8             140
# 9             160
# 10            101
# 11            101
# 12            121
# 13            121
# 14            121
# 15            182
# 16            182
# 17            182
# 18             48
# 19             70
# 20             70
# 21             68
# 22             68
# 23            102
# 24             68
# 25             68
# 26             68
# 27            102
# 28             88
# 29            145
# 30             58
# 31             76
# 32             60
# 33             76
# 34             76
# 35             76
# 36             76
# 37             86
# 38             86
# 39             86
# 40             86
# 41            101
# 42            100
# 43             78
# 44             70
# 45             70
# 46             90
# 47            176
# 48            176
# 49            262
# 50             68
# 51             68
# 52             68
# 53             68
# 54             68
# 55            101
# 56            101
# 57            101
# 58            135
# 59             84
# 60             84
# 61             84
# 62             84
# 63             64
# 64             84
# 65            120
# 66             72
# 67            123
# 68            123
# 69            123
# 70            123
# 71            155
# 72            155
# 73            184
# 74            184
# 75            175
# 76             68
# 77             68
# 78             68
# 79            102
# 80            116
# 81             88
# 82            145
# 83            145
# 84            145
# 85             88
# 86             88
# 87            116
# 88            116
# 89             69
# 90             55
# 91             69
# 92             69
# 93             69
# 94             69
# 95             69
# 96             69
# 97             69
# 98             69
# 99             97
# 100            97
# 101           152
# 102           152
# 103           152
# 104           160
# 105           200
# 106           160
# 107            97
# 108            95
# 109            97
# 110            95
# 111            95
# 112            95
# 113            95
# 114            95
# 115            97
# 116            95
# 117           142
# 118            68
# 119           102
# 120            68
# 121            68
# 122            68
# 123            88
# 124           145
# 125           143
# 126           207
# 127           207
# 128           207
# 129           288
# 130    104.256158
# 131    104.256158
# 132           110
# 133           110
# 134           110
# 135           110
# 136           160
# 137           160
# 138            69
# 139            73
# 140            73
# 141            82
# 142            82
# 143            94
# 144            82
# 145           111
# 146            82
# 147            94
# 148            82
# 149           111
# 150            62
# 151            62
# 152            62
# 153            62
# 154            62
# 155            62
# 156            70
# 157            70
# 158            56
# 159            56
# 160            70
# 161            70
# 162            70
# 163            70
# 164            70
# 165           112
# 166           112
# 167           116
# 168           116
# 169           116
# 170           116
# 171           116
# 172           116
# 173            92
# 174            73
# 175            92
# 176            92
# 177            92
# 178           161
# 179           161
# 180           156
# 181           156
# 182            52
# 183            85
# 184            52
# 185            85
# 186            85
# 187            68
# 188           100
# 189            90
# 190            90
# 191           110
# 192            68
# 193            88
# 194           114
# 195           114
# 196           114
# 197           114
# 198           162
# 199           162
# 200           114
# 201           160
# 202           134
# 203           106
# 204           114
# Name: horsepower, dtype: object

# %% [markdown]
# <h4>the mean value for "peak-rpm" column</h4>

# %%
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)
# Out:
# Average peak rpm: 5125.369458128079

# %% [markdown]
# <h4>Replace "NaN" with the mean value in the "peak-rpm" column</h4>

# %%
df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)

# %%
df['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %% [markdown]
# four doors is the most common type.

# %%
#We can also use the ".idxmax()" method to calculate the most common type automatically:
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
#replace the missing 'num-of-doors' values by the most frequent 
df["num-of-doors"].replace(np.nan, "four", inplace=True)

# %% [markdown]
# dropping all rows that do not have price data:

# %%
# simply drop whole row with NaN in "price" column
df.dropna(subset=["price"], axis=0, inplace=True)

# reset index, because we droped two rows
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %% [markdown]
# data set with no missing values.

# %% [markdown]
# ### Correct data format

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# <p>As you can see above, some columns are not of the correct data type. Numerical variables should have type 'float' or 'int', and variables with strings such as categories should have type 'object'. For example, the numerical values 'bore' and 'stroke' describe the engines, so you should expect them to be of the type 'float' or 'int'; however, they are shown as type 'object'. You have to convert data types into a proper format for each column using the "astype()" method.</p>

# %% [markdown]
# <h4>Convert data types to proper format</h4>

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ## Data Standardization

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
# 3   66.2    54.3         2337         ohc             four          109
# 4   66.4    54.3         2824         ohc             five          136
#
#   fuel-system  bore  stroke  compression-ratio horsepower  peak-rpm  city-mpg  \
# 0        mpfi  3.47    2.68                9.0        111    5000.0        21
# 1        mpfi  3.47    2.68                9.0        111    5000.0        21
# 2        mpfi  2.68    3.47                9.0        154    5000.0        19
# 3        mpfi  3.19    3.40               10.0        102    5500.0        24
# 4        mpfi  3.19    3.40                8.0        115    5500.0        18
#
#    highway-mpg    price
# 0           27  13495.0
# 1           27  16500.0
# 2           26  16500.0
# 3           30  13950.0
# 4           22  17450.0

# %%
# Convert mpg to L/100km by mathematical operation (235 divided by mpg)
df['city-L/100km'] = 235/df["city-mpg"]

# check your transformed data 
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
# 3   66.2    54.3         2337         ohc             four          109
# 4   66.4    54.3         2824         ohc             five          136
#
#   fuel-system  bore  stroke  compression-ratio horsepower  peak-rpm  city-mpg  \
# 0        mpfi  3.47    2.68                9.0        111    5000.0        21
# 1        mpfi  3.47    2.68                9.0        111    5000.0        21
# 2        mpfi  2.68    3.47                9.0        154    5000.0        19
# 3        mpfi  3.19    3.40               10.0        102    5500.0        24
# 4        mpfi  3.19    3.40                8.0        115    5500.0        18
#
#    highway-mpg    price  city-L/100km
# 0           27  13495.0     11.190476
# 1           27  16500.0     11.190476
# 2           26  16500.0     12.368421
# 3           30  13950.0      9.791667
# 4           22  17450.0     13.055556

# %%
df["highway-mpg"] = 235/df["highway-mpg"]

# rename column name from "highway-mpg" to "highway-L/100km"
df.rename(columns={"highway-mpg":'highway-L/100km'}, inplace=True)

# check your transformed data 
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
# 3   66.2    54.3         2337         ohc             four          109
# 4   66.4    54.3         2824         ohc             five          136
#
#   fuel-system  bore  stroke  compression-ratio horsepower  peak-rpm  city-mpg  \
# 0        mpfi  3.47    2.68                9.0        111    5000.0        21
# 1        mpfi  3.47    2.68                9.0        111    5000.0        21
# 2        mpfi  2.68    3.47                9.0        154    5000.0        19
# 3        mpfi  3.19    3.40               10.0        102    5500.0        24
# 4        mpfi  3.19    3.40                8.0        115    5500.0        18
#
#    highway-L/100km    price  city-L/100km
# 0         8.703704  13495.0     11.190476
# 1         8.703704  16500.0     11.190476
# 2         9.038462  16500.0     12.368421
# 3         7.833333  13950.0      9.791667
# 4        10.681818  17450.0     13.055556

# %%
#df.drop('highwayL/100km' , axis = 1 , inplace = True)

df.reset_index(drop = True , inplace = True)
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
# 3   66.2    54.3         2337         ohc             four          109
# 4   66.4    54.3         2824         ohc             five          136
#
#   fuel-system  bore  stroke  compression-ratio horsepower  peak-rpm  city-mpg  \
# 0        mpfi  3.47    2.68                9.0        111    5000.0        21
# 1        mpfi  3.47    2.68                9.0        111    5000.0        21
# 2        mpfi  2.68    3.47                9.0        154    5000.0        19
# 3        mpfi  3.19    3.40               10.0        102    5500.0        24
# 4        mpfi  3.19    3.40                8.0        115    5500.0        18
#
#    highway-L/100km    price  city-L/100km
# 0         8.703704  13495.0     11.190476
# 1         8.703704  16500.0     11.190476
# 2         9.038462  16500.0     12.368421
# 3         7.833333  13950.0      9.791667
# 4        10.681818  17450.0     13.055556

# %% [markdown]
# ## Data Normalization

# %%
# replace (original value) by (original value)/(maximum value)
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()

# %%
df['height'] = df['height']/df['height'].max() 

# show the scaled columns
df[["length","width","height"]].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# ## Binning

# %% [markdown]
#  Convert data to correct format:

# %%
df["horsepower"]=df["horsepower"].astype(int, copy=True)

# %% [markdown]
# the distribution of horsepower.

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          111               Low
# 2          154            Medium
# 3          102               Low
# 4          115               Low
# 5          110               Low
# 6          110               Low
# 7          110               Low
# 8          140            Medium
# 9          101               Low
# 10         101               Low
# 11         121            Medium
# 12         121            Medium
# 13         121            Medium
# 14         182            Medium
# 15         182            Medium
# 16         182            Medium
# 17          48               Low
# 18          70               Low
# 19          70               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# <h3>Bins Visualization</h3>

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot


# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(df["horsepower"], bins = 3)

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# The plot above shows the binning result for the attribute "horsepower".

# %% [markdown]
# ## Indicator Variable

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-L/100km', 'price', 'city-L/100km', 'horsepower-binned'],
#       dtype='object')

# %% [markdown]
# assigning it to data frame "dummy_variable_1":

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %% [markdown]
# Changingthe column names for clarity:

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
# merge data frame "df" and "dummy_variable_1" 
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "df"
df.drop("fuel-type", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length     width  \
# 0  convertible          rwd           front        88.6  0.811148  0.890278
# 1  convertible          rwd           front        88.6  0.811148  0.890278
# 2    hatchback          rwd           front        94.5  0.822681  0.909722
# 3        sedan          fwd           front        99.8  0.848630  0.919444
# 4        sedan          4wd           front        99.4  0.848630  0.922222
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0  0.816054         2548        dohc             four          130
# 1  0.816054         2548        dohc             four          130
# 2  0.876254         2823        ohcv              six          152
# 3  0.908027         2337         ohc             four          109
# 4  0.908027         2824         ohc             five          136
#
#   fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        mpfi  3.47    2.68                9.0         111    5000.0
# 1        mpfi  3.47    2.68                9.0         111    5000.0
# 2        mpfi  2.68    3.47                9.0         154    5000.0
# 3        mpfi  3.19    3.40               10.0         102    5500.0
# 4        mpfi  3.19    3.40                8.0         115    5500.0
#
#    city-mpg  highway-L/100km    price  city-L/100km horsepower-binned  \
# 0        21         8.703704  13495.0     11.190476               Low
# 1        21         8.703704  16500.0     11.190476               Low
# 2        19         9.038462  16500.0     12.368421            Medium
# 3        24         7.833333  13950.0      9.791667               Low
# 4        18        10.681818  17450.0     13.055556               Low
#
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
# get indicator variables of aspiration and assign it to data frame "dummy_variable_2"
dummy_variable_2 = pd.get_dummies(df['aspiration'])

# change column names for clarity
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)

# show first 5 instances of data frame "dummy_variable_1"
dummy_variable_2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # get indicator variables of aspiration and assign it to data frame "dummy_variable_2"
# ----> 2 dummy_variable_2 = pd.get_dummies(df['aspiration'])
#       4 # change column names for clarity
#       5 dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)
#
# NameError: name 'pd' is not defined

# %%
#dummy_variable_2.value_counts()

# merge the new dataframe to the original datafram
df = pd.concat([df, dummy_variable_2], axis=1)

# drop original column "aspiration" from "df"
df.drop('aspiration', axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[229], line 8
#       5 df = pd.concat([df, dummy_variable_2], axis=1)
#       7 # drop original column "aspiration" from "df"
# ----> 8 df.drop('aspiration', axis = 1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4575, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4573     labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4574     if errors == "raise" and labels_missing:
# -> 4575         raise KeyError(f"{labels} not found in axis")
#    4577 if is_extension_array_dtype(mask.dtype):
#    4578     # GH#45860
#    4579     mask = mask.to_numpy(dtype=bool)
#
# KeyError: "['aspiration'] not found in axis"

# %%
# df.drop("std_aspiration", axis = 1, inplace=True)
# df.drop("turbo_aspiration", axis = 1, inplace=True)

df
# Out:
#      symboling  normalized-losses           make num-of-doors   body-style  \
# 0            3                122    alfa-romero          two  convertible
# 1            3                122    alfa-romero          two  convertible
# 2            1                122    alfa-romero          two    hatchback
# 3            2                164           audi         four        sedan
# 4            2                164           audi         four        sedan
# 5            2                122           audi          two        sedan
# 6            1                158           audi         four        sedan
# 7            1                122           audi         four        wagon
# 8            1                158           audi         four        sedan
# 9            2                192            bmw          two        sedan
# 10           0                192            bmw         four        sedan
# 11           0                188            bmw          two        sedan
# 12           0                188            bmw         four        sedan
# 13           1                122            bmw         four        sedan
# 14           0                122            bmw         four        sedan
# 15           0                122            bmw          two        sedan
# 16           0                122            bmw         four        sedan
# 17           2                121      chevrolet          two    hatchback
# 18           1                 98      chevrolet          two    hatchback
# 19           0                 81      chevrolet         four        sedan
# 20           1                118          dodge          two    hatchback
# 21           1                118          dodge          two    hatchback
# 22           1                118          dodge          two    hatchback
# 23           1                148          dodge         four    hatchback
# 24           1                148          dodge         four        sedan
# 25           1                148          dodge         four        sedan
# 26           1                148          dodge         four        sedan
# 27          -1                110          dodge         four        wagon
# 28           3                145          dodge          two    hatchback
# 29           2                137          honda          two    hatchback
# 30           2                137          honda          two    hatchback
# 31           1                101          honda          two    hatchback
# 32           1                101          honda          two    hatchback
# 33           1                101          honda          two    hatchback
# 34           0                110          honda         four        sedan
# 35           0                 78          honda         four        wagon
# 36           0                106          honda          two    hatchback
# 37           0                106          honda          two    hatchback
# 38           0                 85          honda         four        sedan
# 39           0                 85          honda         four        sedan
# 40           0                 85          honda         four        sedan
# 41           1                107          honda          two        sedan
# 42           0                122          isuzu         four        sedan
# 43           2                122          isuzu          two    hatchback
# 44           0                145         jaguar         four        sedan
# 45           0                122         jaguar         four        sedan
# 46           0                122         jaguar          two        sedan
# 47           1                104          mazda          two    hatchback
# 48           1                104          mazda          two    hatchback
# 49           1                104          mazda          two    hatchback
# 50           1                113          mazda         four        sedan
# 51           1                113          mazda         four        sedan
# 52           3                150          mazda          two    hatchback
# 53           3                150          mazda          two    hatchback
# 54           3                150          mazda          two    hatchback
# 55           3                150          mazda          two    hatchback
# 56           1                129          mazda          two    hatchback
# 57           0                115          mazda         four        sedan
# 58           1                129          mazda          two    hatchback
# 59           0                115          mazda         four        sedan
# 60           0                122          mazda         four        sedan
# 61           0                115          mazda         four    hatchback
# 62           0                118          mazda         four        sedan
# 63           0                122          mazda         four        sedan
# 64          -1                 93  mercedes-benz         four        sedan
# 65          -1                 93  mercedes-benz         four        wagon
# 66           0                 93  mercedes-benz          two      hardtop
# 67          -1                 93  mercedes-benz         four        sedan
# 68          -1                122  mercedes-benz         four        sedan
# 69           3                142  mercedes-benz          two  convertible
# 70           0                122  mercedes-benz         four        sedan
# 71           1                122  mercedes-benz          two      hardtop
# 72           1                122        mercury          two    hatchback
# 73           2                161     mitsubishi          two    hatchback
# 74           2                161     mitsubishi          two    hatchback
# 75           2                161     mitsubishi          two    hatchback
# 76           1                161     mitsubishi          two    hatchback
# 77           3                153     mitsubishi          two    hatchback
# 78           3                153     mitsubishi          two    hatchback
# 79           3                122     mitsubishi          two    hatchback
# 80           3                122     mitsubishi          two    hatchback
# 81           3                122     mitsubishi          two    hatchback
# 82           1                125     mitsubishi         four        sedan
# 83           1                125     mitsubishi         four        sedan
# 84           1                125     mitsubishi         four        sedan
# 85          -1                137     mitsubishi         four        sedan
# 86           1                128         nissan          two        sedan
# 87           1                128         nissan          two        sedan
# 88           1                128         nissan          two        sedan
# 89           1                122         nissan         four        sedan
# 90           1                103         nissan         four        wagon
# 91           1                128         nissan          two        sedan
# 92           1                128         nissan          two    hatchback
# 93           1                122         nissan         four        sedan
# 94           1                103         nissan         four        wagon
# 95           2                168         nissan          two      hardtop
# 96           0                106         nissan         four    hatchback
# 97           0                106         nissan         four        sedan
# 98           0                128         nissan         four        sedan
# 99           0                108         nissan         four        wagon
# 100          0                108         nissan         four        sedan
# 101          3                194         nissan          two    hatchback
# 102          3                194         nissan          two    hatchback
# 103          1                231         nissan          two    hatchback
# 104          0                161         peugot         four        sedan
# 105          0                161         peugot         four        sedan
# 106          0                122         peugot         four        wagon
# 107          0                122         peugot         four        wagon
# 108          0                161         peugot         four        sedan
# 109          0                161         peugot         four        sedan
# 110          0                122         peugot         four        wagon
# 111          0                122         peugot         four        wagon
# 112          0                161         peugot         four        sedan
# 113          0                161         peugot         four        sedan
# 114          0                161         peugot         four        sedan
# 115          1                119       plymouth          two    hatchback
# 116          1                119       plymouth          two    hatchback
# 117          1                154       plymouth         four    hatchback
# 118          1                154       plymouth         four        sedan
# 119          1                154       plymouth         four        sedan
# 120         -1                 74       plymouth         four        wagon
# 121          3                122       plymouth          two    hatchback
# 122          3                186        porsche          two    hatchback
# 123          3                122        porsche          two      hardtop
# 124          3                122        porsche          two      hardtop
# 125          3                122        porsche          two  convertible
# 126          0                122        renault         four        wagon
# 127          2                122        renault          two    hatchback
# 128          3                150           saab          two    hatchback
# 129          2                104           saab         four        sedan
# 130          3                150           saab          two    hatchback
# 131          2                104           saab         four        sedan
# 132          3                150           saab          two    hatchback
# 133          2                104           saab         four        sedan
# 134          2                 83         subaru          two    hatchback
# 135          2                 83         subaru          two    hatchback
# 136          2                 83         subaru          two    hatchback
# 137          0                102         subaru         four        sedan
# 138          0                102         subaru         four        sedan
# 139          0                102         subaru         four        sedan
# 140          0                102         subaru         four        sedan
# 141          0                102         subaru         four        sedan
# 142          0                 89         subaru         four        wagon
# 143          0                 89         subaru         four        wagon
# 144          0                 85         subaru         four        wagon
# 145          0                 85         subaru         four        wagon
# 146          1                 87         toyota          two    hatchback
# 147          1                 87         toyota          two    hatchback
# 148          1                 74         toyota         four    hatchback
# 149          0                 77         toyota         four        wagon
# 150          0                 81         toyota         four        wagon
# 151          0                 91         toyota         four        wagon
# 152          0                 91         toyota         four        sedan
# 153          0                 91         toyota         four    hatchback
# 154          0                 91         toyota         four        sedan
# 155          0                 91         toyota         four    hatchback
# 156          0                 91         toyota         four        sedan
# 157          0                 91         toyota         four    hatchback
# 158          0                 91         toyota         four        sedan
# 159          1                168         toyota          two        sedan
# 160          1                168         toyota          two    hatchback
# 161          1                168         toyota          two        sedan
# 162          1                168         toyota          two    hatchback
# 163          2                134         toyota          two      hardtop
# 164          2                134         toyota          two      hardtop
# 165          2                134         toyota          two    hatchback
# 166          2                134         toyota          two      hardtop
# 167          2                134         toyota          two    hatchback
# 168          2                134         toyota          two  convertible
# 169         -1                 65         toyota         four        sedan
# 170         -1                 65         toyota         four        sedan
# 171         -1                 65         toyota         four    hatchback
# 172         -1                 65         toyota         four        sedan
# 173         -1                 65         toyota         four    hatchback
# 174          3                197         toyota          two    hatchback
# 175          3                197         toyota          two    hatchback
# 176         -1                 90         toyota         four        sedan
# 177         -1                122         toyota         four        wagon
# 178          2                122     volkswagen          two        sedan
# 179          2                122     volkswagen          two        sedan
# 180          2                 94     volkswagen         four        sedan
# 181          2                 94     volkswagen         four        sedan
# 182          2                 94     volkswagen         four        sedan
# 183          2                 94     volkswagen         four        sedan
# 184          2                 94     volkswagen         four        sedan
# 185          3                122     volkswagen          two  convertible
# 186          3                256     volkswagen          two    hatchback
# 187          0                122     volkswagen         four        sedan
# 188          0                122     volkswagen         four        sedan
# 189          0                122     volkswagen         four        wagon
# 190         -2                103          volvo         four        sedan
# 191         -1                 74          volvo         four        wagon
# 192         -2                103          volvo         four        sedan
# 193         -1                 74          volvo         four        wagon
# 194         -2                103          volvo         four        sedan
# 195         -1                 74          volvo         four        wagon
# 196         -1                 95          volvo         four        sedan
# 197         -1                 95          volvo         four        sedan
# 198         -1                 95          volvo         four        sedan
# 199         -1                 95          volvo         four        sedan
# 200         -1                 95          volvo         four        sedan
#
#     drive-wheels engine-location  wheel-base    length     width    height  \
# 0            rwd           front        88.6  0.811148  0.890278  0.816054
# 1            rwd           front        88.6  0.811148  0.890278  0.816054
# 2            rwd           front        94.5  0.822681  0.909722  0.876254
# 3            fwd           front        99.8  0.848630  0.919444  0.908027
# 4            4wd           front        99.4  0.848630  0.922222  0.908027
# 5            fwd           front        99.8  0.851994  0.920833  0.887960
# 6            fwd           front       105.8  0.925997  0.991667  0.931438
# 7            fwd           front       105.8  0.925997  0.991667  0.931438
# 8            fwd           front       105.8  0.925997  0.991667  0.934783
# 9            rwd           front       101.2  0.849592  0.900000  0.908027
# 10           rwd           front       101.2  0.849592  0.900000  0.908027
# 11           rwd           front       101.2  0.849592  0.900000  0.908027
# 21          1876         ohc             four           90        2bbl  2.97
# 22          2128         ohc             four           98        mpfi  3.03
# 23          1967         ohc             four           90        2bbl  2.97
# 24          1989         ohc             four           90        2bbl  2.97
# 25          1989         ohc             four           90        2bbl  2.97
# 26          2191         ohc             four           98        mpfi  3.03
# 27          2535         ohc             four          122        2bbl  3.34
# 28          2811         ohc             four          156         mfi  3.60
# 29          1713         ohc             four           92        1bbl  2.91
# 30          1819         ohc             four           92        1bbl  2.91
# 31          1837         ohc             four           79        1bbl  2.91
# 32          1940         ohc             four           92        1bbl  2.91
# 33          1956         ohc             four           92        1bbl  2.91
# 34          2010         ohc             four           92        1bbl  2.91
# 35          2024         ohc             four           92        1bbl  2.92
# 36          2236         ohc             four          110        1bbl  3.15
# 37          2289         ohc             four          110        1bbl  3.15
# 38          2304         ohc             four          110        1bbl  3.15
# 39          2372         ohc             four          110        1bbl  3.15
# 40          2465         ohc             four          110        mpfi  3.15
# 41          2293         ohc             four          110        2bbl  3.15
# 42          2337         ohc             four          111        2bbl  3.31
# 43          2734         ohc             four          119        spfi  3.43
# 44          4066        dohc              six          258        mpfi  3.63
# 45          4066        dohc              six          258        mpfi  3.63
# 46          3950        ohcv           twelve          326        mpfi  3.54
# 47          1890         ohc             four           91        2bbl  3.03
# 48          1900         ohc             four           91        2bbl  3.03
# 49          1905         ohc             four           91        2bbl  3.03
# 50          1945         ohc             four           91        2bbl  3.03
# 51          1950         ohc             four           91        2bbl  3.08
# 52          2380       rotor              two           70        4bbl   NaN
# 53          2380       rotor              two           70        4bbl   NaN
# 54          2385       rotor              two           70        4bbl   NaN
# 55          2500       rotor              two           80        mpfi   NaN
# 56          2385         ohc             four          122        2bbl  3.39
# 57          2410         ohc             four          122        2bbl  3.39
# 58          2385         ohc             four          122        2bbl  3.39
# 59          2410         ohc             four          122        2bbl  3.39
# 60          2443         ohc             four          122         idi  3.39
# 61          2425         ohc             four          122        2bbl  3.39
# 62          2670         ohc             four          140        mpfi  3.76
# 63          2700         ohc             four          134         idi  3.43
# 64          3515         ohc             five          183         idi  3.58
# 65          3750         ohc             five          183         idi  3.58
# 66          3495         ohc             five          183         idi  3.58
# 67          3770         ohc             five          183         idi  3.58
# 68          3740        ohcv            eight          234        mpfi  3.46
# 69          3685        ohcv            eight          234        mpfi  3.46
# 70          3900        ohcv            eight          308        mpfi  3.80
# 71          3715        ohcv            eight          304        mpfi  3.80
# 72          2910         ohc             four          140        mpfi  3.78
# 73          1918         ohc             four           92        2bbl  2.97
# 74          1944         ohc             four           92        2bbl  2.97
# 75          2004         ohc             four           92        2bbl  2.97
# 76          2145         ohc             four           98        spdi  3.03
# 77          2370         ohc             four          110        spdi  3.17
# 78          2328         ohc             four          122        2bbl  3.35
# 79          2833         ohc             four          156        spdi  3.58
# 80          2921         ohc             four          156        spdi  3.59
# 81          2926         ohc             four          156        spdi  3.59
# 82          2365         ohc             four          122        2bbl  3.35
# 83          2405         ohc             four          122        2bbl  3.35
# 84          2403         ohc             four          110        spdi  3.17
# 85          2403         ohc             four          110        spdi  3.17
# 86          1889         ohc             four           97        2bbl  3.15
# 87          2017         ohc             four          103         idi  2.99
# 88          1918         ohc             four           97        2bbl  3.15
# 89          1938         ohc             four           97        2bbl  3.15
# 90          2024         ohc             four           97        2bbl  3.15
# 91          1951         ohc             four           97        2bbl  3.15
# 92          2028         ohc             four           97        2bbl  3.15
# 93          1971         ohc             four           97        2bbl  3.15
# 94          2037         ohc             four           97        2bbl  3.15
# 95          2008         ohc             four           97        2bbl  3.15
# 96          2324         ohc             four          120        2bbl  3.33
# 97          2302         ohc             four          120        2bbl  3.33
# 98          3095        ohcv              six          181        mpfi  3.43
# 99          3296        ohcv              six          181        mpfi  3.43
# 100         3060        ohcv              six          181        mpfi  3.43
# 101         3071        ohcv              six          181        mpfi  3.43
# 102         3139        ohcv              six          181        mpfi  3.43
# 103         3139        ohcv              six          181        mpfi  3.43
# 104         3020           l             four          120        mpfi  3.46
# 105         3197           l             four          152         idi  3.70
# 106         3230           l             four          120        mpfi  3.46
# 107         3430           l             four          152         idi  3.70
# 108         3075           l             four          120        mpfi  3.46
# 109         3252           l             four          152         idi  3.70
# 110         3285           l             four          120        mpfi  3.46
# 111         3485           l             four          152         idi  3.70
# 112         3075           l             four          120        mpfi  3.46
# 113         3252           l             four          152         idi  3.70
# 114         3130           l             four          134        mpfi  3.61
# 115         1918         ohc             four           90        2bbl  2.97
# 116         2128         ohc             four           98        spdi  3.03
# 117         1967         ohc             four           90        2bbl  2.97
# 118         1989         ohc             four           90        2bbl  2.97
# 119         2191         ohc             four           98        2bbl  2.97
# 120         2535         ohc             four          122        2bbl  3.35
# 121         2818         ohc             four          156        spdi  3.59
# 122         2778         ohc             four          151        mpfi  3.94
# 123         2756        ohcf              six          194        mpfi  3.74
# 124         2756        ohcf              six          194        mpfi  3.74
# 125         2800        ohcf              six          194        mpfi  3.74
# 126         2579         ohc             four          132        mpfi  3.46
# 127         2460         ohc             four          132        mpfi  3.46
# 128         2658         ohc             four          121        mpfi  3.54
# 129         2695         ohc             four          121        mpfi  3.54
# 130         2707         ohc             four          121        mpfi  2.54
# 131         2758         ohc             four          121        mpfi  3.54
# 132         2808        dohc             four          121        mpfi  3.54
# 133         2847        dohc             four          121        mpfi  3.54
# 134         2050        ohcf             four           97        2bbl  3.62
# 135         2120        ohcf             four          108        2bbl  3.62
# 136         2240        ohcf             four          108        2bbl  3.62
# 137         2145        ohcf             four          108        2bbl  3.62
# 138         2190        ohcf             four          108        2bbl  3.62
# 139         2340        ohcf             four          108        mpfi  3.62
# 140         2385        ohcf             four          108        2bbl  3.62
# 141         2510        ohcf             four          108        mpfi  3.62
# 142         2290        ohcf             four          108        2bbl  3.62
# 143         2455        ohcf             four          108        mpfi  3.62
# 144         2420        ohcf             four          108        2bbl  3.62
# 145         2650        ohcf             four          108        mpfi  3.62
# 146         1985         ohc             four           92        2bbl  3.05
# 147         2040         ohc             four           92        2bbl  3.05
# 148         2015         ohc             four           92        2bbl  3.05
# 149         2280         ohc             four           92        2bbl  3.05
# 150         2290         ohc             four           92        2bbl  3.05
# 151         3110         ohc             four           92        2bbl  3.05
# 152         2081         ohc             four           98        2bbl  3.19
# 153         2109         ohc             four           98        2bbl  3.19
# 154         2275         ohc             four          110         idi  3.27
# 155         2275         ohc             four          110         idi  3.27
# 156         2094         ohc             four           98        2bbl  3.19
# 157         2122         ohc             four           98        2bbl  3.19
# 158         2140         ohc             four           98        2bbl  3.19
# 159         2169         ohc             four           98        2bbl  3.19
# 160         2204         ohc             four           98        2bbl  3.19
# 161         2265        dohc             four           98        mpfi  3.24
# 162         2300        dohc             four           98        mpfi  3.24
# 163         2540         ohc             four          146        mpfi  3.62
# 164         2536         ohc             four          146        mpfi  3.62
# 165         2551         ohc             four          146        mpfi  3.62
# 166         2679         ohc             four          146        mpfi  3.62
# 167         2714         ohc             four          146        mpfi  3.62
# 168         2975         ohc             four          146        mpfi  3.62
# 169         2326         ohc             four          122        mpfi  3.31
# 170         2480         ohc             four          110         idi  3.27
# 171         2414         ohc             four          122        mpfi  3.31
# 172         2414         ohc             four          122        mpfi  3.31
# 173         2458         ohc             four          122        mpfi  3.31
# 174         2976        dohc              six          171        mpfi  3.27
# 175         3016        dohc              six          171        mpfi  3.27
# 176         3131        dohc              six          171        mpfi  3.27
# 177         3151        dohc              six          161        mpfi  3.27
# 178         2261         ohc             four           97         idi  3.01
# 179         2209         ohc             four          109        mpfi  3.19
# 180         2264         ohc             four           97         idi  3.01
# 181         2212         ohc             four          109        mpfi  3.19
# 182         2275         ohc             four          109        mpfi  3.19
# 183         2319         ohc             four           97         idi  3.01
# 184         2300         ohc             four          109        mpfi  3.19
# 185         2254         ohc             four          109        mpfi  3.19
# 186         2221         ohc             four          109        mpfi  3.19
# 187         2661         ohc             five          136        mpfi  3.19
# 188         2579         ohc             four           97         idi  3.01
# 189         2563         ohc             four          109        mpfi  3.19
# 190         2912         ohc             four          141        mpfi  3.78
# 191         3034         ohc             four          141        mpfi  3.78
# 192         2935         ohc             four          141        mpfi  3.78
# 193         3042         ohc             four          141        mpfi  3.78
# 194         3045         ohc             four          130        mpfi  3.62
# 195         3157         ohc             four          130        mpfi  3.62
# 196         2952         ohc             four          141        mpfi  3.78
# 197         3049         ohc             four          141        mpfi  3.78
# 198         3012        ohcv              six          173        mpfi  3.58
# 199         3217         ohc              six          145         idi  3.01
# 200         3062         ohc             four          141        mpfi  3.78
#
#        stroke  compression-ratio  horsepower     peak-rpm  city-mpg  \
# 0    2.680000               9.00         111  5000.000000        21
# 1    2.680000               9.00         111  5000.000000        21
# 2    3.470000               9.00         154  5000.000000        19
# ...
# 77          7.833333   9959.0     10.217391               Low
# 78          7.343750   8499.0      9.400000               Low
# 79          9.791667  12629.0     12.368421            Medium
# 80          9.791667  14869.0     12.368421            Medium
# 81          9.791667  14489.0     12.368421            Medium
# 82          7.343750   6989.0      9.400000               Low
# 83          7.343750   8189.0      9.400000               Low
# 84          7.833333   9279.0     10.217391               Low
# 85          7.833333   9279.0     10.217391               Low
# 86          6.351351   5499.0      7.580645               Low
# 87          4.700000   7099.0      5.222222               Low
# 88          6.351351   6649.0      7.580645               Low
# 89          6.351351   6849.0      7.580645               Low
# 90          6.351351   7349.0      7.580645               Low
# 91          6.351351   7299.0      7.580645               Low
# 92          6.351351   7799.0      7.580645               Low
# 93          6.351351   7499.0      7.580645               Low
# 94          6.351351   7999.0      7.580645               Low
# 95          6.351351   8249.0      7.580645               Low
# 96          6.911765   8949.0      8.703704               Low
# 97          6.911765   9549.0      8.703704               Low
# 98         10.681818  13499.0     13.823529            Medium
# 99         10.681818  14399.0     13.823529            Medium
# 100         9.400000  13499.0     12.368421            Medium
# 101         9.400000  17199.0     12.368421            Medium
# 102        10.217391  19699.0     13.823529              High
# 103         9.400000  18399.0     12.368421            Medium
# 104         9.791667  11900.0     12.368421               Low
# 105         7.121212  13200.0      8.392857               Low
# 106         9.791667  12440.0     12.368421               Low
# 107         9.400000  13860.0      9.400000               Low
# 108         9.791667  15580.0     12.368421               Low
# 109         7.121212  16900.0      8.392857               Low
# 110         9.791667  16695.0     12.368421               Low
# 111         9.400000  17075.0      9.400000               Low
# 112         9.791667  16630.0     12.368421               Low
# 113         7.121212  17950.0      8.392857               Low
# 114         9.791667  18150.0     13.055556            Medium
# 115         5.731707   5572.0      6.351351               Low
# 116         7.833333   7957.0      9.791667               Low
# 117         6.184211   6229.0      7.580645               Low
# 118         6.184211   6692.0      7.580645               Low
# 119         6.184211   7609.0      7.580645               Low
# 120         7.833333   8921.0      9.791667               Low
# 121         9.791667  12764.0     12.368421            Medium
# 122         8.703704  22018.0     12.368421            Medium
# 123         9.400000  32528.0     13.823529              High
# 124         9.400000  34028.0     13.823529              High
# 125         9.400000  37028.0     13.823529              High
# 126         7.580645   9295.0     10.217391               Low
# 127         7.580645   9895.0     10.217391               Low
# 128         8.392857  11850.0     11.190476               Low
# 129         8.392857  12170.0     11.190476               Low
# 130         8.392857  15040.0     11.190476               Low
# 131         8.392857  15510.0     11.190476               Low
# 132         9.038462  18150.0     12.368421            Medium
# 133         9.038462  18620.0     12.368421            Medium
# 134         6.527778   5118.0      7.580645               Low
# 135         7.580645   7053.0      9.038462               Low
# 136         7.580645   7603.0      9.038462               Low
# 137         6.351351   7126.0      7.343750               Low
# 138         7.121212   7775.0      8.392857               Low
# 139         7.343750   9960.0      9.038462               Low
# 140         9.400000   9233.0      9.791667               Low
# 141         8.103448  11259.0      9.791667               Low
# 142         7.343750   7463.0      8.392857               Low
# 143         7.580645  10198.0      9.400000               Low
# 144         8.103448   8013.0     10.217391               Low
# 145        10.217391  11694.0     10.217391               Low
# 146         6.025641   5348.0      6.714286               Low
# 147         6.184211   6338.0      7.580645               Low
# 148         6.184211   6488.0      7.580645               Low
# 149         6.351351   6918.0      7.580645               Low
# 150         7.343750   7898.0      8.703704               Low
# 151         7.343750   8778.0      8.703704               Low
# 152         6.351351   6938.0      7.833333               Low
# 153         6.351351   7198.0      7.833333               Low
# 154         6.527778   7898.0      6.911765               Low
# 155         5.000000   7788.0      6.184211               Low
# 156         5.000000   7738.0      6.184211               Low
# 157         6.911765   8358.0      8.392857               Low
# 158         6.911765   9258.0      8.392857               Low
# 159         6.911765   8058.0      8.103448               Low
# 160         6.911765   8238.0      8.103448               Low
# 161         8.103448   9298.0      9.038462               Low
# 162         8.103448   9538.0      9.038462               Low
# 163         7.833333   8449.0      9.791667               Low
# 164         7.833333   9639.0      9.791667               Low
# 165         7.833333   9989.0      9.791667               Low
# 166         7.833333  11199.0      9.791667               Low
# 167         7.833333  11549.0      9.791667               Low
# 168         7.833333  17669.0      9.791667               Low
# 169         6.911765   8948.0      8.103448               Low
# 170         7.121212  10698.0      7.833333               Low
# 171         7.343750   9988.0      8.703704               Low
# 172         7.343750  10898.0      8.703704               Low
# 173         7.343750  11248.0      8.703704               Low
# 174         9.791667  16558.0     11.750000            Medium
# 175         9.791667  15998.0     12.368421            Medium
# 176         9.791667  15690.0     11.750000            Medium
# 177         9.791667  15750.0     12.368421            Medium
# 178         5.108696   7775.0      6.351351               Low
# 179         6.911765   7975.0      8.703704               Low
# 180         5.108696   7995.0      6.351351               Low
# 181         6.911765   8195.0      8.703704               Low
# 182         6.911765   8495.0      8.703704               Low
# 183         5.595238   9495.0      6.351351               Low
# 184         7.343750   9995.0      9.038462               Low
# 185         8.103448  11595.0      9.791667               Low
# 186         8.103448   9980.0      9.791667               Low
# 187         9.791667  13295.0     12.368421               Low
# 188         6.184211  13845.0      7.121212               Low
# 189         7.580645  12290.0      9.400000               Low
# 190         8.392857  12940.0     10.217391               Low
# 191         8.392857  13415.0     10.217391               Low
# 192         8.392857  15985.0      9.791667               Low
# 193         8.392857  16515.0      9.791667               Low
# 194        10.681818  18420.0     13.823529            Medium
# 195        10.681818  18950.0     13.823529            Medium
# 196         8.392857  16845.0     10.217391               Low
# 197         9.400000  19045.0     12.368421            Medium
# 198        10.217391  21485.0     13.055556            Medium
# 199         8.703704  22470.0      9.038462               Low
# 200         9.400000  22625.0     12.368421               Low
#
#      fuel-type-diesel  fuel-type-gas
# 0                   0              1
# 1                   0              1
# 2                   0              1
# 3                   0              1
# 4                   0              1
# 5                   0              1
# 6                   0              1
# 7                   0              1
# 8                   0              1
# 9                   0              1
# 10                  0              1
# 11                  0              1
# 12                  0              1
# 13                  0              1
# 14                  0              1
# 15                  0              1
# 16                  0              1
# 17                  0              1
# 18                  0              1
# 19                  0              1
# 20                  0              1
# 21                  0              1
# 22                  0              1
# 23                  0              1
# 24                  0              1
# 25                  0              1
# 26                  0              1
# 27                  0              1
# 28                  0              1
# 29                  0              1
# 30                  0              1
# 31                  0              1
# 32                  0              1
# 33                  0              1
# 34                  0              1
# 35                  0              1
# 36                  0              1
# 37                  0              1
